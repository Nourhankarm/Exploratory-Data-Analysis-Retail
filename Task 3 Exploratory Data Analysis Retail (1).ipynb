# %%
#Target : find out the weak areas where you can work to make more profit.

# %%
#importing libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#Import Dataset
data=pd.read_csv("SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Use the drop function 
data.drop(["Postal Code","Quantity",],axis=1, inplace = True)
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#      Region         Category Sub-Category     Sales  Discount    Profit
# 0     South        Furniture    Bookcases  261.9600      0.00   41.9136
# 1     South        Furniture       Chairs  731.9400      0.00  219.5820
# 2      West  Office Supplies       Labels   14.6200      0.00    6.8714
# 3     South        Furniture       Tables  957.5775      0.45 -383.0310
# 4     South  Office Supplies      Storage   22.3680      0.20    2.5164
# ...     ...              ...          ...       ...       ...       ...
# 9989  South        Furniture  Furnishings   25.2480      0.20    4.1028
# 9990   West        Furniture  Furnishings   91.9600      0.00   15.6332
# 9991   West       Technology       Phones  258.5760      0.20   19.3932
# 9992   West  Office Supplies        Paper   29.6000      0.00   13.3200
# 9993   West  Office Supplies   Appliances  243.1600      0.00   72.9480
#
# [9994 rows x 11 columns]

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200      0.00    6.8714
# 3  South        Furniture       Tables  957.5775      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680      0.20    2.5164

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.describe()
# Out:
#               Sales     Discount       Profit
# count   9994.000000  9994.000000  9994.000000
# mean     229.858001     0.156203    28.656896
# std      623.245101     0.206452   234.260108
# min        0.444000     0.000000 -6599.978000
# 25%       17.280000     0.000000     1.728750
# 50%       54.490000     0.200000     8.666500
# 75%      209.940000     0.200000    29.364000
# max    22638.480000     0.800000  8399.976000

# %%
correlation =data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
data["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x= data['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
data["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.countplot(x= data['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
data["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(x= data['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
data["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,15))
plt.pie(data["Sub-Category"].value_counts(), labels= data["Sub-Category"].value_counts().index, autopct ="%2f")
plt.show()

# %%
#Here, Sub-Category with highest sale is Binder, follwed by Paper and Furnishings as second and third respectively.
st_profit=data.groupby(["State"])["Profit"].sum().nlargest(20)
st_profit
# Out:
# State
# California       76381.3871
# New York         74038.5486
# Washington       33402.6517
# Michigan         24463.1876
# Virginia         18597.9504
# Indiana          18382.9363
# Georgia          16250.0433
# Kentucky         11199.6966
# Minnesota        10823.1874
# Delaware          9977.3748
# New Jersey        9772.9138
# Wisconsin         8401.8004
# Rhode Island      7285.6293
# Maryland          7031.1788
# Massachusetts     6785.5016
# Missouri          6436.2105
# Alabama           5786.8253
# Oklahoma          4853.9560
# Arkansas          4008.6871
# Connecticut       3511.4918
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(15,8))
st_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
sns.lineplot(data=data, x="Discount", y= "Profit")
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
data.plot(kind="scatter",x="Sales",y="Profit", c="Discount", colormap="Set1",figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
data1= data.groupby("State")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
data1[:].plot.bar(color = ["Green","Red"], figsize=(20,12))
plt.title("Profit-Loss and Sales across States")
plt.show()

# %%
#Profit-Loss and Sales across Region
data1= data.groupby("Region")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
data1[:].plot.bar(color = ["Blue","Red"], figsize=(10,7))
plt.title("Profit-Loss and Sales across Region")
plt.show()
